# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cust = pd.read_csv('cleaned_customer_data.csv')
total = pd.read_csv('transaction_data.csv')

# %%
cust_total = pd.merge(cust, total, left_on='Cust_id', right_on='CustID', how='inner')
cust_total.head(10)
# Out:
#    Cust_id      Date_x      Time    Name                      Email  \
# 0        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 1        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 2        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 3        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 4        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 5        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 6        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 7        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 8        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
# 9        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
#
#           Phone Sms-opt-out  Sms_opt_out  TransactionID  CustID  ...  \
# 0  212-555-1001           N        False          10258       1  ...
# 1  212-555-1001           N        False          10351       1  ...
# ...

# %%
customer_summary = cust_total[['CustID', 'ProductName', 'Employee']]
customer_summary
# Out:
#       CustID                       ProductName         Employee
# 0          1                Mascarpone Fabioli    Nancy Davolio
# 1          1                      Cte de Blaye    Nancy Davolio
# 2          1   Jack's New England Clam Chowder    Nancy Davolio
# 3          1  Louisiana Fiery Hot Pepper Sauce    Nancy Davolio
# 4          1                Rhnbru Klosterbier    Nancy Davolio
# ...      ...                               ...              ...
# 1348      89               Sir Rodney's Scones  Steven Buchanan
# 1349      89                  Chartreuse verte  Steven Buchanan
# 1350      89      Chef Anton's Cajun Seasoning      Robert King
# 1351      89            Thringer Rostbratwurst   Laura Callahan
# 1352      89     Singaporean Hokkien Fried Mee   Laura Callahan
#
# [1353 rows x 3 columns]
